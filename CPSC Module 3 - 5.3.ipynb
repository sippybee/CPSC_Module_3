# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.util import ngrams, bigrams, trigrams
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to /Users/art/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/art/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/art/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sentence = "Baker calls the phenomenon implied satiety"

# %%
# Unigram (n=1)

# %%
tokens = word_tokenize(sentence)
tokens
# Out:
# ['Baker', 'calls', 'the', 'phenomenon', 'implied', 'satiety']

# %%
# Bigrams (n=2)
bigram_list = list(bigrams(tokens))
print(bigram_list)
# Out:
# [('Baker', 'calls'), ('calls', 'the'), ('the', 'phenomenon'), ('phenomenon', 'implied'), ('implied', 'satiety')]

# %%
# Trigrams (n=3)

# %%
trigram_list = list(trigrams(tokens))
print(trigram_list)
# Out:
# [('Baker', 'calls', 'the'), ('calls', 'the', 'phenomenon'), ('the', 'phenomenon', 'implied'), ('phenomenon', 'implied', 'satiety')]

# %%
print(set("Full Sense Device".split()))
# Out:
# {'Device', 'Sense', 'Full'}

# %%
print(set("Device Sense Full".split()))
# Out:
# {'Device', 'Full', 'Sense'}

# %%
list(bigrams("Full Sense Device".split()))
# Out:
# [('Full', 'Sense'), ('Sense', 'Device')]

# %%
list(bigrams("Device Sense Full".split()))
# Out:
# [('Device', 'Sense'), ('Sense', 'Full')]

# %%
with open(r"article.txt") as f:
    text = f.read()
    
tokens = [t.lower() for t in word_tokenize(text) if t.isalpha() and t not in stopwords.words('english')]
# list(bigrams(tokens))
bigrams = list(ngrams(tokens, 3))
for bg, count in Counter(bigrams).most_common(10):
    print(bg, count)
# Out:
# ('full', 'sense', 'device') 21
# ('grand', 'health', 'partners') 3
# ('sense', 'device', 'could') 2
# ('gastric', 'bypass', 'surgery') 2
# ('signals', 'brain', 'saying') 2
# ('brain', 'saying', 'i') 2
# ('grand', 'rapids', 'practice') 2
# ('lost', 'weight', 'continued') 2
# ('weight', 'continued', 'lose') 2
# ('continued', 'lose', 'weight') 2

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...
